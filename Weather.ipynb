# %%
import pandas as pd
import numpy as np
from IPython.core.display import display, HTML
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9924\1992838572.py:3: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython.display
#   from IPython.core.display import display, HTML

# %%
Weather=pd.read_csv("GlobalWeatherRepository.csv")
Weather.head()
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1715849100  2024-05-16 13:15                 26.6
# 1          1715849100  2024-05-16 10:45                 19.0
# 2          1715849100  2024-05-16 09:45                 23.0
# 3          1715849100  2024-05-16 10:45                  6.3
# 4          1715849100  2024-05-16 09:45                 26.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    79.8  Partly Cloudy  ...                8.4
# ...

# %%
Weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39399 entries, 0 to 39398
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       39399 non-null  object
#  1   location_name                 39399 non-null  object
#  2   latitude                      39399 non-null  float64
#  3   longitude                     39399 non-null  float64
#  4   timezone                      39399 non-null  object
#  5   last_updated_epoch            39399 non-null  int64
#  6   last_updated                  39399 non-null  object
#  7   temperature_celsius           39399 non-null  float64
#  8   temperature_fahrenheit        39399 non-null  float64
#  9   condition_text                39399 non-null  object
#  10  wind_mph                      39399 non-null  float64
#  11  wind_kph                      39399 non-null  float64
# ...

# %%
html_content = """

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Metadata for GlobalWeatherRepository</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            line-height: 1.6;
        }
         img {
            display: block;
            margin: 20px auto;
            width: 200px; 
        }
        table {
            width: 100%;
            border-collapse: collapse;
            margin: 20px 0;
        }
        th, td {
            border: 1px solid #ddd;
            padding: 8px;
            text-align: left;
        }
        th {
            background-color: #f4f4f4;
        }
        tr:nth-child(even) {
            background-color: #f9f9f9;
        }
    </style>
</head>
<body>
    <img src="Weather.jpg" alt="Weather Image">
    
    <h1>Metadata for <code>GlobalWeatherRepository.csv</code></h1>

    <h2>General Information</h2>
    <ul>
        <li><strong>Number of rows:</strong> 39,399</li>
        <li><strong>Number of columns:</strong> 41</li>
    </ul>

    <h2>Variables and Their Definitions</h2>
    <table>
        <thead>
            <tr>
                <th>Variable</th>
                <th>Type</th>
                <th>Description</th>
            </tr>
        </thead>
        <tbody>
            <tr>
                <td><strong>country</strong></td>
                <td>string</td>
                <td>Name of the country where the weather data is recorded.</td>
            </tr>
            <tr>
                <td><strong>location_name</strong></td>
                <td>string</td>
                <td>Specific location or city within the country.</td>
            </tr>
            <tr>
                <td><strong>latitude</strong></td>
                <td>float</td>
                <td>Latitude of the location in decimal degrees.</td>
            </tr>
            <tr>
                <td></strong>longitude<strong></td>
                <td>float</td>
                <td>Longitude of the location in decimal degrees.</td>
            </tr>
            <tr>
                <td><strong>timezone</strong></td>
                <td>string</td>
                <td>Timezone of the location.</td>
            </tr>
            <tr>
                <td><strong>last_updated</strong></td>
                <td>string</td>
                <td>Timestamp of the most recent weather update.</td>
            </tr>
            <tr>
                <td><strong>temperature_celsius</strong></td>
                <td>float</td>
                <td>Current temperature in Celsius.</td>
            </tr>
            <tr>
                <td><strong>temperature_fahrenheit</strong></td>
                <td>float</td>
                <td>Current temperature in Fahrenheit.</td>
            </tr>
            <tr>
                <td><strong>condition_text</strong></td>
                <td>string</td>
                <td>Description of the current weather condition (e.g., Clear, Cloudy).</td>
            </tr>
            <tr>
                <td><strong>wind_mph</strong></td>
                <td>float</td>
                <td>Wind speed in miles per hour.</td>
            </tr>
            <tr>
                <td><strong>humidity</strong></td>
                <td>int</td>
                <td>Humidity percentage (0–100).</td>
            </tr>
            <tr>
                <td><strong>air_quality_Carbon_Monoxide</strong></td>
                <td>float</td>
                <td>Carbon Monoxide level in the air (measured in μg/m³).</td>
            </tr>
            <tr>
                <td><strong>sunrise</strong></td>
                <td>string</td>
                <td>Time of sunrise at the location.</td>
            </tr>
            <tr>
                <td><strong>sunset</strong></td>
                <td>string</td>
                <td>Time of sunset at the location.</td>
            </tr>
        </tbody>
    </table>
</body>
</html>
"""
display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Metadata for GlobalWeatherRepository</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             line-height: 1.6;
#         }
#          img {
#             display: block;
#             margin: 20px auto;
#             width: 200px;
#         }
#         table {
#             width: 100%;
#             border-collapse: collapse;
#             margin: 20px 0;
#         }
#         th, td {
#             border: 1px solid #ddd;
#             padding: 8px;
#             text-align: left;
#         }
#         th {
#             background-color: #f4f4f4;
#         }
#         tr:nth-child(even) {
#             background-color: #f9f9f9;
#         }
#     </style>
# </head>
# <body>
#     <img src="Weather.jpg" alt="Weather Image">
#
# ...
